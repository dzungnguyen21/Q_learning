# %%
import numpy as np
import random
from collections import defaultdict
import matplotlib.pyplot as plt

# Constants
PLAYER_X = 1
PLAYER_O = -1
EMPTY = 0
ALPHA = 0.1  # Learning rate
GAMMA = 0.9  # Discount factor
EPSILON = 0.1  # Exploration rate
BOARD_SIZE_4x4 = 4
BOARD_SIZE_5x5 = 5
# Function to create an empty board
def create_board(size):
    return np.zeros((size, size), dtype=int)

# Function to check for a winner
def check_winner(board):
    size = board.shape[0]
    for player in [PLAYER_X, PLAYER_O]:
        # Check rows, columns, and diagonals for a win
        for i in range(size):
            if all(board[i, :] == player) or all(board[:, i] == player):
                return player
        if all([board[i, i] == player for i in range(size)]) or all([board[i, size - 1 - i] == player for i in range(size)]):
            return player
    if np.all(board != EMPTY):
        return 0  # Draw
    return None  # Game not finished

class QLearning_Agent:
    def __init__(self, size):
        self.size = size
        self.q_values = defaultdict(lambda: np.zeros(size * size))  # Q(s,a)
    
    def state_to_string(self, board):
        """Convert board state to a string for a hashable state."""
        return str(board.reshape(self.size * self.size))

    def get_possible_actions(self, board):
        """Get possible actions (empty cells)."""
        return list(zip(*np.where(board == EMPTY)))

    def choose_action(self, board, player):
        """Epsilon-greedy policy to choose the next action."""
        state = self.state_to_string(board)
        possible_actions = self.get_possible_actions(board)
        if np.random.rand() < EPSILON:
            # Explore: choose random action
            return possible_actions[np.random.choice(len(possible_actions))]
        else:
            # Exploit: choose the best action based on Q-values
            q_values_state = self.q_values[state]
            best_action = None
            best_value = -np.inf
            for action in possible_actions:
                action_index = action[0] * self.size + action[1]
                if q_values_state[action_index] > best_value:
                    best_value = q_values_state[action_index]
                    best_action = action
            return best_action

    def update_q_values(self, state, action, reward, next_state):
        """Q-learning update rule for Q-values."""
        state_key = self.state_to_string(state)
        next_state_key = self.state_to_string(next_state)

        action_index = action[0] * self.size + action[1]
        
        # Q-learning update formula: Q(s,a) += ALPHA * (reward + GAMMA * max(Q(s',a')) - Q(s,a))
        best_next_action_value = np.max(self.q_values[next_state_key])  # Max value for the next state
        
        # Update the Q-value for the current state and action
        self.q_values[state_key][action_index] += ALPHA * (reward + GAMMA * best_next_action_value - self.q_values[state_key][action_index])

    def play_game(self, opponent='random'):
        """Simulate a game between the Q-learning agent and a random opponent."""
        board = create_board(self.size)
        player = PLAYER_X
        history = []

        # Initialize the first action
        state = board.copy()
        action = self.choose_action(board, player)

        while True:
            history.append((state.copy(), action))
            board[action] = player

            winner = check_winner(board)
            if winner is not None:
                reward = 1 if winner == PLAYER_X else -1 if winner == PLAYER_O else 0
                self.update_q_values(state, action, reward, board)  # Final step
                return winner

            # Switch player
            player = -player

            # If opponent is random
            if opponent == 'random':
                # Opponent (PLAYER_O) random action
                if player == PLAYER_O:
                    opponent_action = random.choice(self.get_possible_actions(board))
                    board[opponent_action] = PLAYER_O
                    winner = check_winner(board)
                    if winner is not None:
                        reward = -1 if winner == PLAYER_O else 0
                        self.update_q_values(state, action, reward, board)
                        return winner
                    player = -player  # Switch back to agent

            # Next state and action for the Q-learning agent
            next_state = board.copy()
            reward = 0  # No reward for intermediate steps

            self.update_q_values(state, action, reward, next_state)

            # Update state and action for the next iteration
            state = next_state
            action = self.choose_action(board, PLAYER_X)

    def train(self, episodes):
        win_count = 0
        win_rates = []

        for episode in range(episodes):
            winner = self.play_game()
            if winner == PLAYER_X:
                win_count += 1

            if (episode + 1) % 100 == 0:
                win_rate = win_count / (episode + 1)
                win_rates.append(win_rate)
                print(f"Episode {episode + 1}: Win rate = {win_rate:.3f}")

        return win_rates

def plot_win_rate(win_rates, board_size):
    plt.plot(win_rates)
    plt.xlabel('Episodes (x100)')
    plt.ylabel('Win Rate')
    plt.title(f'Agent Win Rate Over Time (Board Size: {board_size}x{board_size})')
    plt.show()

# %%
if __name__ == '__main__':
    agent_4x4 = QLearning_Agent(BOARD_SIZE_4x4)
    win_rate_4x4 = agent_4x4.train(10000)
    
    # Plotting win rate\
    plot_win_rate(win_rate_4x4, BOARD_SIZE_4x4)

    # Train and plot for 5x5 board
    agent_5x5 = QLearning_Agent(BOARD_SIZE_5x5)
    win_rates_5x5 = agent_5x5.train(10000)
    plot_win_rate(win_rates_5x5, BOARD_SIZE_5x5)
# Out:
# Episode 100: Win rate = 0.640
# Episode 200: Win rate = 0.675
# Episode 300: Win rate = 0.643
# Episode 400: Win rate = 0.645
# Episode 500: Win rate = 0.658
# Episode 600: Win rate = 0.663
# Episode 700: Win rate = 0.670
# Episode 800: Win rate = 0.669
# Episode 900: Win rate = 0.667
# Episode 1000: Win rate = 0.672
# Episode 1100: Win rate = 0.668
# Episode 1200: Win rate = 0.667
# Episode 1300: Win rate = 0.667
# Episode 1400: Win rate = 0.671
# Episode 1500: Win rate = 0.671
# Episode 1600: Win rate = 0.676
# Episode 1700: Win rate = 0.681
# Episode 1800: Win rate = 0.682
# Episode 1900: Win rate = 0.685
# Episode 2000: Win rate = 0.683
# Episode 2100: Win rate = 0.679
# Episode 2200: Win rate = 0.678
# Episode 2300: Win rate = 0.682
# Episode 2400: Win rate = 0.680
# Episode 2500: Win rate = 0.678
# Episode 2600: Win rate = 0.678
# Episode 2700: Win rate = 0.676
# Episode 2800: Win rate = 0.678
# Episode 2900: Win rate = 0.678
# Episode 3000: Win rate = 0.682
# Episode 3100: Win rate = 0.682
# Episode 3200: Win rate = 0.682
# Episode 3300: Win rate = 0.681
# Episode 3400: Win rate = 0.680
# Episode 3500: Win rate = 0.681
# Episode 3600: Win rate = 0.680
# Episode 3700: Win rate = 0.679
# Episode 3800: Win rate = 0.678
# Episode 3900: Win rate = 0.677
# Episode 4000: Win rate = 0.676
# Episode 4100: Win rate = 0.676
# Episode 4200: Win rate = 0.676
# Episode 4300: Win rate = 0.675
# Episode 4400: Win rate = 0.676
# Episode 4500: Win rate = 0.676
# Episode 4600: Win rate = 0.676
# Episode 4700: Win rate = 0.675
# Episode 4800: Win rate = 0.674
# Episode 4900: Win rate = 0.674
# Episode 5000: Win rate = 0.675
# Episode 5100: Win rate = 0.673
# Episode 5200: Win rate = 0.673
# Episode 5300: Win rate = 0.673
# Episode 5400: Win rate = 0.673
# Episode 5500: Win rate = 0.672
# Episode 5600: Win rate = 0.673
# Episode 5700: Win rate = 0.674
# Episode 5800: Win rate = 0.674
# Episode 5900: Win rate = 0.675
# Episode 6000: Win rate = 0.675
# Episode 6100: Win rate = 0.676
# Episode 6200: Win rate = 0.676
# Episode 6300: Win rate = 0.677
# Episode 6400: Win rate = 0.677
# Episode 6500: Win rate = 0.677
# Episode 6600: Win rate = 0.677
# Episode 6700: Win rate = 0.676
# Episode 6800: Win rate = 0.676
# Episode 6900: Win rate = 0.675
# Episode 7000: Win rate = 0.675
# Episode 7100: Win rate = 0.675
# Episode 7200: Win rate = 0.676
# Episode 7300: Win rate = 0.677
# Episode 7400: Win rate = 0.677
# Episode 7500: Win rate = 0.677
# Episode 7600: Win rate = 0.678
# Episode 7700: Win rate = 0.679
# Episode 7800: Win rate = 0.679
# Episode 7900: Win rate = 0.677
# Episode 8000: Win rate = 0.677
# Episode 8100: Win rate = 0.678
# Episode 8200: Win rate = 0.677
# Episode 8300: Win rate = 0.678
# Episode 8400: Win rate = 0.679
# Episode 8500: Win rate = 0.678
# Episode 8600: Win rate = 0.679
# Episode 8700: Win rate = 0.679
# Episode 8800: Win rate = 0.679
# Episode 8900: Win rate = 0.679
# Episode 9000: Win rate = 0.679
# Episode 9100: Win rate = 0.679
# Episode 9200: Win rate = 0.680
# Episode 9300: Win rate = 0.680
# Episode 9400: Win rate = 0.681
# Episode 9500: Win rate = 0.679
# Episode 9600: Win rate = 0.680
# Episode 9700: Win rate = 0.680
# Episode 9800: Win rate = 0.680
# Episode 9900: Win rate = 0.680
# Episode 10000: Win rate = 0.680
# Episode 100: Win rate = 0.620
# Episode 200: Win rate = 0.640
# Episode 300: Win rate = 0.660
# Episode 400: Win rate = 0.662
# Episode 500: Win rate = 0.658
# Episode 600: Win rate = 0.657
# Episode 700: Win rate = 0.661
# Episode 800: Win rate = 0.664
# Episode 900: Win rate = 0.670
# Episode 1000: Win rate = 0.674
# Episode 1100: Win rate = 0.676
# Episode 1200: Win rate = 0.675
# Episode 1300: Win rate = 0.672
# Episode 1400: Win rate = 0.671
# Episode 1500: Win rate = 0.672
# Episode 1600: Win rate = 0.672
# Episode 1700: Win rate = 0.674
# Episode 1800: Win rate = 0.674
# Episode 1900: Win rate = 0.672
# Episode 2000: Win rate = 0.671
# Episode 2100: Win rate = 0.670
# Episode 2200: Win rate = 0.670
# Episode 2300: Win rate = 0.667
# Episode 2400: Win rate = 0.669
# Episode 2500: Win rate = 0.669
# Episode 2600: Win rate = 0.668
# Episode 2700: Win rate = 0.670
# Episode 2800: Win rate = 0.668
# Episode 2900: Win rate = 0.669
# Episode 3000: Win rate = 0.670
# Episode 3100: Win rate = 0.671
# Episode 3200: Win rate = 0.672
# Episode 3300: Win rate = 0.675
# Episode 3400: Win rate = 0.674
# Episode 3500: Win rate = 0.673
# Episode 3600: Win rate = 0.673
# Episode 3700: Win rate = 0.674
# Episode 3800: Win rate = 0.673
# Episode 3900: Win rate = 0.671
# Episode 4000: Win rate = 0.671
# Episode 4100: Win rate = 0.672
# Episode 4200: Win rate = 0.673
# Episode 4300: Win rate = 0.673
# Episode 4400: Win rate = 0.674
# Episode 4500: Win rate = 0.673
# Episode 4600: Win rate = 0.674
# Episode 4700: Win rate = 0.672
# Episode 4800: Win rate = 0.673
# Episode 4900: Win rate = 0.675
# Episode 5000: Win rate = 0.675
# Episode 5100: Win rate = 0.674
# Episode 5200: Win rate = 0.675
# Episode 5300: Win rate = 0.675
# Episode 5400: Win rate = 0.676
# Episode 5500: Win rate = 0.677
# Episode 5600: Win rate = 0.678
# Episode 5700: Win rate = 0.677
# Episode 5800: Win rate = 0.675
# Episode 5900: Win rate = 0.675
# Episode 6000: Win rate = 0.674
# Episode 6100: Win rate = 0.674
# Episode 6200: Win rate = 0.675
# Episode 6300: Win rate = 0.676
# Episode 6400: Win rate = 0.675
# Episode 6500: Win rate = 0.675
# Episode 6600: Win rate = 0.675
# Episode 6700: Win rate = 0.675
# Episode 6800: Win rate = 0.674
# Episode 6900: Win rate = 0.675
# Episode 7000: Win rate = 0.674
# Episode 7100: Win rate = 0.674
# Episode 7200: Win rate = 0.675
# Episode 7300: Win rate = 0.675
# Episode 7400: Win rate = 0.676
# Episode 7500: Win rate = 0.675
# Episode 7600: Win rate = 0.674
# Episode 7700: Win rate = 0.674
# Episode 7800: Win rate = 0.675
# Episode 7900: Win rate = 0.674
# Episode 8000: Win rate = 0.675
# Episode 8100: Win rate = 0.675
# Episode 8200: Win rate = 0.675
# Episode 8300: Win rate = 0.676
# Episode 8400: Win rate = 0.675
# Episode 8500: Win rate = 0.675
# Episode 8600: Win rate = 0.674
# Episode 8700: Win rate = 0.673
# Episode 8800: Win rate = 0.672
# Episode 8900: Win rate = 0.672
# Episode 9000: Win rate = 0.673
# Episode 9100: Win rate = 0.673
# Episode 9200: Win rate = 0.672
# Episode 9300: Win rate = 0.672
# Episode 9400: Win rate = 0.672
# Episode 9500: Win rate = 0.672
# Episode 9600: Win rate = 0.673
# Episode 9700: Win rate = 0.673
# Episode 9800: Win rate = 0.673
# Episode 9900: Win rate = 0.673
# Episode 10000: Win rate = 0.674
